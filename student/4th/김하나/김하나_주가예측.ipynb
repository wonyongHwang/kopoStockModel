# %% [markdown]
# # PBR 로 적정 주가 산출 후 현재 주가가 적정 주가보다 20% 이상 낮을 경우 매수

# %%
#PER 
#적정 PER -> 낮을수록 좋다. 10이하 6~4정도면 좋음
#5년 평균 PER * EPS = 적정주가 
#적정주가 /1.2 OR 0.8 = 20% 낮은 가격 ->매수 
#적정주가 /현재주가 = 1 -> 현재주가가 적정하다 
#0.96 -> 4퍼센트정도 과대평가 
#1.04 -> 4%정도 낮은 주가 

#PBR
#적정 PBR -> 낮을 수록 좋다. 1이면 현재 적정주가라는 것, 그 이하라면 좋음 
#가장 최근 PBS (PBS는 그간 쌓인 자산이니 가장 최근 값을 보면 된다)
#5년 평균 PBR * BPS = 적정주가 * 0.8 -> 매수 

#미래 주가 예측 
#미래 적정 주가 = 미래의 EPS(애널리스트 추정치) * 적정PER(5년간의 평균)

# %%
# 3가지 주가예측 방법으로 3년간의 주가를 체크해보고 주가 흐름과 가장 근접한 방법을 선택함 

#testCode
#url = 'https://finance.naver.com/item/main.nhn?code=005930'
#table_df_list = pd.read_html(url, encoding='euc-kr')    # 한글이 깨짐. utf-8도 깨짐. 그래서 'euc-kr'로 설정함  
#table_df = table_df_list[3]

#eps_2018 = table_df.iloc[9,1]
#per_2018 = table_df.iloc[10,1]
#bps_2018 = table_df.iloc[11,1]
#pbr_2018 = table_df.iloc[12,1]
#roe_2018 = table_df.iloc[5,1]

#eps_2019 = table_df.iloc[9,2]
#per_2019 = table_df.iloc[10,2]
#bps_2019 = table_df.iloc[11,2]
#pbr_2019 = table_df.iloc[12,2]
#roe_2019 = table_df.iloc[5,2]

#eps_2021 = table_df.iloc[9,-2]
#per_2021 = table_df.iloc[10,-2]
#bps_2021 = table_df.iloc[11,-2]
#pbr_2021 = table_df.iloc[12,-2]
#roe_2021 = table_df.iloc[5,-2]

#eps_2020 = table_df.iloc[9,3]
#per_2020 = table_df.iloc[10,3]
#bps_2020 = table_df.iloc[11,3]
#pbr_2020 = table_df.iloc[12,3]
#roe_2020 = table_df.iloc[5,3]

#eps2018 = eps_2018 * roe_2018 * 100
#titrationPrice_2018 = per_2018 * eps_2018
#pbr2018 =  pbr_2018 * bps_2018
#print(eps2018)
#print(titrationPrice_2018)
#print(pbr2018)

#eps2019 = eps_2019 * roe_2019 * 100
#titrationPrice_2019 = per_2019 * eps_2019
#pbr2019 =  pbr_2019 * bps_2019
#print(eps2019)
#print(titrationPrice_2019)
#print(pbr2019)

#eps2020 = eps_2020 * roe_2020 * 100
#titrationPrice_2020 = per_2020 * eps_2020
#pbr2020 =  pbr_2020 * bps_2020
#print(eps2020)
#print(titrationPrice_2020)
#print(pbr2020)

#eps2021 = eps_2021 * roe_2021 * 100
#titrationPrice_2021 = per_2021 * eps_2021
#pbr2021 = pbr_2021 * bps_2021
#print(eps2021)
#print(titrationPrice_2021)
#print(pbr2021)

# %%
import urllib.parse
from bs4 import BeautifulSoup 
import requests 
import pandas as pd
import time
import datetime
import math

MARKET_CODE_DICT = {
    
    'kospi': 'stockMkt',
    'kosdaq': 'kosdaqMkt',
    'konex': 'konexMkt'
    
}
DOWNLOAD_URL = 'https://kind.krx.co.kr/corpgeneral/corpList.do'
naver_stock = 'https://finance.naver.com/item/main.nhn?code='

# %%
#종목코드 6자리 미만시 사용할 함수 
def zeroFill(columnValue):
    
    columnValue = str(columnValue)
    #앞을 0으로 채워라 제로필
    outValue = columnValue.zfill(6)  

    return outValue

# %%
#코스피 종목 불러올 함수 설정 
def get_stock_codes(market=None, delisted=False):
    
    params = {'method': 'download'}
    
    if market.lower() in MARKET_CODE_DICT:
        
        ## marketType 키 추가
        params['marketType'] = MARKET_CODE_DICT[market]
        #print(market.lower()+" market key is exist")
        
    else:
        
        print("invalid market")

    params_string = urllib.parse.urlencode(params)
    request_url = DOWNLOAD_URL+"?"+params_string
    df = pd.read_html(request_url)[0]
    df["종목코드"] = df.종목코드.apply(zeroFill)
 
    return df

# %%
#종목 테이블에서 종목코드(100개) 가져오는 함수 
def get_code(market):
    
    codeList = []
    stocks = get_stock_codes(market)
    
    for i in range(len(stocks)):  #해당 마켓의 전체 종목 가지고오기 
        
        stock_code = stocks.iloc[i]['종목코드']
        codeList.append(stock_code)
        #stock_name = stocks.iloc[0]['회사명']
        #print(stock_code)
        
    return codeList

# %%
#주가정보 테이블 생성 함수 
def stock_info(stockCode):
    
    try:
    
        url = naver_stock + stockCode #종목코드 url에 추가 
        table_df_list = pd.read_html(url, encoding='euc-kr')    # 한글이 깨짐. utf-8도 깨짐. 그래서 'euc-kr'로 설정함  
        table_df = table_df_list[3] #종목 정보가 담겨있는 테이블 추출 

        return table_df
    
    except:
        
        return None

# %%
#현재년도의 bps와 per 값 구하해 매입목표가격 정의 
def get_target_price(stockInfo): 
    
    try:
        
        bps_this_year = stockInfo.iloc[11,-2] #bps값 정의
        pbr_this_year = stockInfo.iloc[12,-2] #pbr값 정의
        just_price = pbr_this_year * bps_this_year #적정가격 도출 
        target_price = math.ceil(just_price * 0.8) #적정가격보다 20% 더 저렴한 가격 도출 -> 소수점 올림 (절대값으롳 처리했습니다) 
        
    except : #가끔 bps가 존재하지 않는 경우 발생 -> 그럴 경우 말이 안되게 낮은 금액으로 설정해 잘못된 매수의견 출력을 방지함 
        
        target_price = 10
    
    return target_price

# %%
#주식 현재 가격 받아오는 함수 
def get_price(stockCode):
    
    url = naver_stock + stockCode #종목 코드 url에 추가 
    result = requests.get(url)
    html = BeautifulSoup(result.content, "html.parser") #태그에서 현재가격 가지고오기 
    today = html.find("p", {"class":"no_today"}) 
    real_time_tag = today.find("span", {"class":"blind"})
    real_time_price = int(real_time_tag.text.replace(',',"")) #컴마 제거 후 인트형으로 변환 
    
    return real_time_price

# %%
#주식 종목명 가지져오는 함수 
def get_name(market , i):
    
    stocks = get_stock_codes(market)
    stock_name = stocks.iloc[i]['회사명']
        
    return stock_name

# %%
#매수의견 받아오기 
def investment_opinion(stockCode):
    
    try:
    
        url = naver_stock + stockCode
        stock_info_list = pd.read_html(url, encoding='euc-kr')
        stock_info = stock_info_list[7]
        table = stock_info[1][0]
        investment_opinion = table.split("l")[0].strip()[-2:] #테이블에서 투자자 의견 가지고오기
        
        if investment_opinion == '/A' : 
            investment_opinion = None
        
        #투자자 의견이 없음/중립/매수/강력매수인 경우에만 리턴     
        if (investment_opinion =='중립') or (investment_opinion =='매수') or (investment_opinion == '강력매수')  or (investment_opinion == None): 
            return investment_opinion
        
        else :
            return -1
   
    except : 
        return -1

# %%
#요일 계산 함수 (주말에는 프로그램이 돌지 않는다)
def get_days():
    
    result = datetime.datetime.today().weekday()
    
    if (result == 5) or (result == 6) :
        
        return False
    
    else : 
        
        return True

# %%
#시간 가지고 오기 (09:00 ~ 15:30 까지만 자동으로 돌 수 있도록 )
def get_time():
    
    now = datetime.datetime.now()
    time = now.strftime("%H")
    minute = now.strftime("%M")
    result = "{}{}".format(time,minute)
    
    return result

# %%
#로직 1
#사용자가 원할 때 사용할 수 있는 매수/매도 추천 함수 
#매수 추천 결과가 N이 압도적으로 많지만 낮은 빈도로 Y(매수의견) 을 주는것을 확인했습니다!
#매수 추천이 y인 것만 출력할까 했는데 추천 종목 뿐만 아니라 사용자가 자신이 선택한 마켓 (코스피 등)의 여러 종목을 검색해보고  
#네이버 투자자 의견 / 제가 짠 코드의 매수 추천 의견을 동시에 검토해보고 결정할 수 있도록 하면 좋을 것 같아 Y/N모두 출력하게 하였습니다.

def stock_advisor(market):
        
    codeList = get_code(market) #사용자가 입력한 마켓 ( 코스피 / 코스닥 / 코넥스 ) 의 종목코드 전부 가지고오기 

    for i in range(len(codeList)): #종목리스트의 길이만큼 포문 

        stockCode = codeList[i]

        stockInfo = stock_info(stockCode) #종목코드 추출

        if len(stockInfo) > 0  : #테이블 추출에 성공했다면 아래 로직 수행 

            stock_name = get_name(market,i) #종목명 
            target_price = get_target_price(stockInfo) #목표가격
            real_time_price = get_price(stockCode) #현재가격 
            investment = investment_opinion(stockCode) #네이버투자자의견 (매수/강력매수/none인 경우만 )

            result = "" #매수/매도 결정을 담아줄 변수 선언 

            if investment != -1 : #투자자 의견이 매수 / 강력매수 / none 인 경우에만 가격 확인  

                if(real_time_price < target_price): #현재 가격이 우리의 목표가격 ( 우리가 구한 적정가격보다 20% 이상 저렴할 경우 y 아니라면 n)

                    result = "Y"

                else : 
                    
                    result = "N"
                    
                #출력할 문자열 정의 
                pString = "{}. 종목명 : {} / 종목코드 : {} / 목표매수가격 : {} / 현재가격 : {} / 네이버투자의견 : {} / 매수추천 : {}".format(i , stock_name , codeList[i] , target_price , real_time_price , investment , result)

                print(pString) #최종결과 출력

# %%
#로직 2
#자동화를 위한 코드 (매주 월요일에 돌릴 수 있도록 ) 자동화 코드를 추가했습니다
def stock_advisor2(market):
    
    while get_days() : #평일동안 반복문 돌기 
        
        time = get_time() #현재 시간 가지고오기 
        
        if time == "9000" : # 평일 09:00이 되면 프로그램 시작 
            
            while True: #무한반복 
                
                if time == "1530" : #장 마감시 break
                    
                    break
        
                codeList = get_code(market) #사용자가 입력한 마켓 ( 코스피 / 코스닥 / 코넥스 ) 의 종목코드 전부 가지고오기 

                for i in range(len(codeList)): #종목리스트의 길이만큼 포문 
                    
                    stockCode = codeList[i]

                    stockInfo = stock_info(stockCode) #종목코드 추출

                    if len(stockInfo) > 0  : #테이블 추출에 성공했다면 아래 로직 수행 

                        stock_name = get_name(market,i) #종목명 
                        target_price = get_target_price(stockInfo) #목표가격
                        real_time_price = get_price(stockCode) #현재가격 
                        investment = investment_opinion(stockCode) #투자자의견 

                        result = "" #매수/매도 결정을 담아줄 변수 선언 

                        if investment : #투자자 의견이 매수 / 강력매수 / 없음 인 경우에만 가격 확인  

                            if(real_time_price < target_price): #현재 가격이 우리의 목표가격 ( 우리가 구한 적정가격보다 20% 이상 저렴할 경우 y 아니라면 n)

                                result = "Y"

                            else : 
                                
                                result = "N"
                                
                            #출력할 문자열 정의 
                            pString = "{}. 종목명 : {} / 종목코드 : {} / 적정가격 : {} / 현재가격 : {} / 투자의견 : {} / 매수추천 : {}".format(i , stock_name , codeList[i] , target_price , real_time_price , investment , result)

                            print(pString) #최종결과 출력

# %%
stock_advisor('kospi')
# Out:
# 0. 종목명 : DRB동일 / 종목코드 : 004840 / 목표매수가격 : 5343 / 현재가격 : 8010 / 네이버투자의견 : None / 매수추천 : N
# 1. 종목명 : DSR / 종목코드 : 155660 / 목표매수가격 : 4564 / 현재가격 : 7310 / 네이버투자의견 : None / 매수추천 : N
# 2. 종목명 : GS글로벌 / 종목코드 : 001250 / 목표매수가격 : 1997 / 현재가격 : 3130 / 네이버투자의견 : None / 매수추천 : N
# 3. 종목명 : HDC현대산업개발 / 종목코드 : 294870 / 목표매수가격 : 23350 / 현재가격 : 29850 / 네이버투자의견 : 매수 / 매수추천 : N
# 4. 종목명 : KEC / 종목코드 : 092220 / 목표매수가격 : 1857 / 현재가격 : 2515 / 네이버투자의견 : None / 매수추천 : N
# 5. 종목명 : KG동부제철 / 종목코드 : 016380 / 목표매수가격 : 12279 / 현재가격 : 19600 / 네이버투자의견 : None / 매수추천 : N
# 6. 종목명 : KG케미칼 / 종목코드 : 001390 / 목표매수가격 : 21585 / 현재가격 : 31600 / 네이버투자의견 : None / 매수추천 : N
# 7. 종목명 : KTis / 종목코드 : 058860 / 목표매수가격 : 2392 / 현재가격 : 3325 / 네이버투자의견 : None / 매수추천 : N
# 8. 종목명 : LG이노텍 / 종목코드 : 011070 / 목표매수가격 : 164724 / 현재가격 : 223500 / 네이버투자의견 : 매수 / 매수추천 : N
# 9. 종목명 : LG전자 / 종목코드 : 066570 / 목표매수가격 : 119906 / 현재가격 : 158000 / 네이버투자의견 : 매수 / 매수추천 : N
# 10. 종목명 : LG헬로비전 / 종목코드 : 037560 / 목표매수가격 : 3915 / 현재가격 : 8090 / 네이버투자의견 : 중립 / 매수추천 : N
# 11. 종목명 : OCI / 종목코드 : 010060 / 목표매수가격 : 97584 / 현재가격 : 119000 / 네이버투자의견 : 매수 / 매수추천 : N
# 12. 종목명 : SK이노베이션 / 종목코드 : 096770 / 목표매수가격 : 175102 / 현재가격 : 289000 / 네이버투자의견 : 매수 / 매수추천 : N
# 13. 종목명 : STX / 종목코드 : 011810 / 목표매수가격 : 4840 / 현재가격 : 8930 / 네이버투자의견 : None / 매수추천 : N
# 14. 종목명 : WISCOM / 종목코드 : 024070 / 목표매수가격 : 10 / 현재가격 : 6260 / 네이버투자의견 : None / 매수추천 : N
# 15. 종목명 : 갤럭시아에스엠 / 종목코드 : 011420 / 목표매수가격 : 1433 / 현재가격 : 2415 / 네이버투자의견 : None / 매수추천 : N
# 16. 종목명 : 경농 / 종목코드 : 002100 / 목표매수가격 : 10864 / 현재가격 : 16550 / 네이버투자의견 : None / 매수추천 : N
# 17. 종목명 : 경동인베스트 / 종목코드 : 012320 / 목표매수가격 : 32702 / 현재가격 : 40400 / 네이버투자의견 : None / 매수추천 : N
# 18. 종목명 : 국도화학 / 종목코드 : 007690 / 목표매수가격 : 54853 / 현재가격 : 69000 / 네이버투자의견 : None / 매수추천 : N
# 19. 종목명 : 국동 / 종목코드 : 005320 / 목표매수가격 : 3264 / 현재가격 : 3335 / 네이버투자의견 : None / 매수추천 : N
# 20. 종목명 : 극동유화 / 종목코드 : 014530 / 목표매수가격 : 4875 / 현재가격 : 5320 / 네이버투자의견 : None / 매수추천 : N
# 21. 종목명 : 기아 / 종목코드 : 000270 / 목표매수가격 : 66428 / 현재가격 : 88900 / 네이버투자의견 : 매수 / 매수추천 : N
# 22. 종목명 : 까뮤이앤씨 / 종목코드 : 013700 / 목표매수가격 : 1762 / 현재가격 : 2780 / 네이버투자의견 : None / 매수추천 : N
# 23. 종목명 : 대덕전자 / 종목코드 : 353200 / 목표매수가격 : 11166 / 현재가격 : 15950 / 네이버투자의견 : 매수 / 매수추천 : N
# 24. 종목명 : 대우건설 / 종목코드 : 047040 / 목표매수가격 : 5291 / 현재가격 : 8740 / 네이버투자의견 : 매수 / 매수추천 : N
# 25. 종목명 : 대웅 / 종목코드 : 003090 / 목표매수가격 : 26199 / 현재가격 : 38650 / 네이버투자의견 : 중립 / 매수추천 : N
# 26. 종목명 : 덴티움 / 종목코드 : 145720 / 목표매수가격 : 51278 / 현재가격 : 65400 / 네이버투자의견 : 매수 / 매수추천 : N
# 27. 종목명 : 두산인프라코어 / 종목코드 : 042670 / 목표매수가격 : 9079 / 현재가격 : 15500 / 네이버투자의견 : 매수 / 매수추천 : N
# 28. 종목명 : 디피씨 / 종목코드 : 026890 / 목표매수가격 : 10176 / 현재가격 : 14150 / 네이버투자의견 : None / 매수추천 : N
# 29. 종목명 : 락앤락 / 종목코드 : 115390 / 목표매수가격 : 11798 / 현재가격 : 14250 / 네이버투자의견 : None / 매수추천 : N
# 30. 종목명 : 롯데정보통신 / 종목코드 : 286940 / 목표매수가격 : 30534 / 현재가격 : 41400 / 네이버투자의견 : 매수 / 매수추천 : N
# 31. 종목명 : 마니커 / 종목코드 : 027740 / 목표매수가격 : 571 / 현재가격 : 791 / 네이버투자의견 : None / 매수추천 : N
# 32. 종목명 : 메리츠증권 / 종목코드 : 008560 / 목표매수가격 : 3672 / 현재가격 : 4375 / 네이버투자의견 : 중립 / 매수추천 : N
# 33. 종목명 : 명문제약 / 종목코드 : 017180 / 목표매수가격 : 4157 / 현재가격 : 5600 / 네이버투자의견 : None / 매수추천 : N
# 35. 종목명 : 부국증권 / 종목코드 : 001270 / 목표매수가격 : 18272 / 현재가격 : 25200 / 네이버투자의견 : None / 매수추천 : N
# 36. 종목명 : 삼성SDI / 종목코드 : 006400 / 목표매수가격 : 527880 / 현재가격 : 653000 / 네이버투자의견 : 매수 / 매수추천 : N
# 37. 종목명 : 삼성엔지니어링 / 종목코드 : 028050 / 목표매수가격 : 11193 / 현재가격 : 22400 / 네이버투자의견 : 매수 / 매수추천 : N
# 38. 종목명 : 삼성출판사 / 종목코드 : 068290 / 목표매수가격 : 36840 / 현재가격 : 43700 / 네이버투자의견 : None / 매수추천 : N
# 39. 종목명 : 삼성화재해상보험 / 종목코드 : 000810 / 목표매수가격 : 151653 / 현재가격 : 213500 / 네이버투자의견 : 매수 / 매수추천 : N
# 40. 종목명 : 삼영화학공업 / 종목코드 : 003720 / 목표매수가격 : 2192 / 현재가격 : 2925 / 네이버투자의견 : None / 매수추천 : N
# 41. 종목명 : 삼호개발 / 종목코드 : 010960 / 목표매수가격 : 4121 / 현재가격 : 6420 / 네이버투자의견 : None / 매수추천 : N
# 42. 종목명 : 상상인증권 / 종목코드 : 001290 / 목표매수가격 : 961 / 현재가격 : 1470 / 네이버투자의견 : None / 매수추천 : N
# 43. 종목명 : 선진 / 종목코드 : 136490 / 목표매수가격 : 13559 / 현재가격 : 17250 / 네이버투자의견 : None / 매수추천 : N
# 44. 종목명 : 세기상사 / 종목코드 : 002420 / 목표매수가격 : 4925 / 현재가격 : 6160 / 네이버투자의견 : None / 매수추천 : N
# 45. 종목명 : 세방전지 / 종목코드 : 004490 / 목표매수가격 : 62209 / 현재가격 : 101500 / 네이버투자의견 : None / 매수추천 : N
# 46. 종목명 : 세아제강지주 / 종목코드 : 003030 / 목표매수가격 : 44235 / 현재가격 : 70700 / 네이버투자의견 : None / 매수추천 : N
# 47. 종목명 : 세화아이엠씨 / 종목코드 : 145210 / 목표매수가격 : 529 / 현재가격 : 860 / 네이버투자의견 : None / 매수추천 : N
# 49. 종목명 : 신한지주 / 종목코드 : 055550 / 목표매수가격 : 30002 / 현재가격 : 42000 / 네이버투자의견 : 매수 / 매수추천 : N
# 50. 종목명 : 쌍방울 / 종목코드 : 102280 / 목표매수가격 : 488 / 현재가격 : 1275 / 네이버투자의견 : None / 매수추천 : N
# 51. 종목명 : 쌍용자동차 / 종목코드 : 003620 / 목표매수가격 : 2216 / 현재가격 : 2770 / 네이버투자의견 : None / 매수추천 : N
# 52. 종목명 : 쎌마테라퓨틱스 / 종목코드 : 015540 / 목표매수가격 : 5135 / 현재가격 : 6410 / 네이버투자의견 : None / 매수추천 : N
# 53. 종목명 : 영화금속 / 종목코드 : 012280 / 목표매수가격 : 1525 / 현재가격 : 2095 / 네이버투자의견 : None / 매수추천 : N
# 54. 종목명 : 오뚜기 / 종목코드 : 007310 / 목표매수가격 : 456089 / 현재가격 : 556000 / 네이버투자의견 : 매수 / 매수추천 : N
# 55. 종목명 : 우진 / 종목코드 : 105840 / 목표매수가격 : 3800 / 현재가격 : 9260 / 네이버투자의견 : None / 매수추천 : N
# 56. 종목명 : 윌비스 / 종목코드 : 008600 / 목표매수가격 : 1340 / 현재가격 : 2605 / 네이버투자의견 : None / 매수추천 : N
# 57. 종목명 : 유나이티드 / 종목코드 : 033270 / 목표매수가격 : 39522 / 현재가격 : 51700 / 네이버투자의견 : None / 매수추천 : N
# 58. 종목명 : 이월드 / 종목코드 : 084680 / 목표매수가격 : 2716 / 현재가격 : 3775 / 네이버투자의견 : None / 매수추천 : N
# 59. 종목명 : 인지컨트롤스 / 종목코드 : 023800 / 목표매수가격 : 11573 / 현재가격 : 17450 / 네이버투자의견 : None / 매수추천 : N
# 60. 종목명 : 인터지스 / 종목코드 : 129260 / 목표매수가격 : 3433 / 현재가격 : 4230 / 네이버투자의견 : None / 매수추천 : N
# 61. 종목명 : 일성건설 / 종목코드 : 013360 / 목표매수가격 : 1154 / 현재가격 : 2870 / 네이버투자의견 : None / 매수추천 : N
# 62. 종목명 : 일진다이아 / 종목코드 : 081000 / 목표매수가격 : 32316 / 현재가격 : 44350 / 네이버투자의견 : None / 매수추천 : N
# 63. 종목명 : 자화전자 / 종목코드 : 033240 / 목표매수가격 : 13406 / 현재가격 : 20550 / 네이버투자의견 : 매수 / 매수추천 : N
# 64. 종목명 : 제일약품 / 종목코드 : 271980 / 목표매수가격 : 31925 / 현재가격 : 42750 / 네이버투자의견 : None / 매수추천 : N
# 65. 종목명 : 제일파마홀딩스 / 종목코드 : 002620 / 목표매수가격 : 14412 / 현재가격 : 25000 / 네이버투자의견 : None / 매수추천 : N
# 66. 종목명 : 조비 / 종목코드 : 001550 / 목표매수가격 : 16955 / 현재가격 : 24300 / 네이버투자의견 : None / 매수추천 : N
# 67. 종목명 : 조흥 / 종목코드 : 002600 / 목표매수가격 : 142623 / 현재가격 : 201000 / 네이버투자의견 : None / 매수추천 : N
# 68. 종목명 : 종근당홀딩스 / 종목코드 : 001630 / 목표매수가격 : 82959 / 현재가격 : 109000 / 네이버투자의견 : 매수 / 매수추천 : N
# 69. 종목명 : 지역난방공사 / 종목코드 : 071320 / 목표매수가격 : 31284 / 현재가격 : 46000 / 네이버투자의견 : 매수 / 매수추천 : N
# 70. 종목명 : 코오롱인더 / 종목코드 : 120110 / 목표매수가격 : 47588 / 현재가격 : 67300 / 네이버투자의견 : 매수 / 매수추천 : N
# 71. 종목명 : 키다리스튜디오 / 종목코드 : 020120 / 목표매수가격 : 11259 / 현재가격 : 15100 / 네이버투자의견 : 매수 / 매수추천 : N
# 72. 종목명 : 태경산업 / 종목코드 : 015890 / 목표매수가격 : 6338 / 현재가격 : 6860 / 네이버투자의견 : None / 매수추천 : N
# 73. 종목명 : 태양금속공업 / 종목코드 : 004100 / 목표매수가격 : 1286 / 현재가격 : 1775 / 네이버투자의견 : None / 매수추천 : N
# 74. 종목명 : 포스코 / 종목코드 : 005490 / 목표매수가격 : 253766 / 현재가격 : 345000 / 네이버투자의견 : 매수 / 매수추천 : N
# 75. 종목명 : 포스코강판 / 종목코드 : 058430 / 목표매수가격 : 23115 / 현재가격 : 61600 / 네이버투자의견 : None / 매수추천 : N
# 76. 종목명 : 한국공항 / 종목코드 : 005430 / 목표매수가격 : 32905 / 현재가격 : 51600 / 네이버투자의견 : None / 매수추천 : N
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-d7d60cd151a1> in <module>
# ----> 1 stock_advisor('kospi')
#
# <ipython-input-12-493420d02606> in stock_advisor(market)
#      19             stock_name = get_name(market,i) #종목명
#      20             target_price = get_target_price(stockInfo) #목표가격
# ---> 21             real_time_price = get_price(stockCode) #현재가격
#      22             investment = investment_opinion(stockCode) #네이버투자자의견 (매수/강력매수/none인 경우만 )
#      23
#
# <ipython-input-7-07d9083b7de7> in get_price(stockCode)
#       4     url = naver_stock + stockCode #종목 코드 url에 추가
#       5     result = requests.get(url)
# ----> 6     html = BeautifulSoup(result.content, "html.parser") #태그에서 현재가격 가지고오기
#       7     today = html.find("p", {"class":"no_today"})
#       8     real_time_tag = today.find("span", {"class":"blind"})
#
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     320          self.contains_replacement_characters) in (
#     321              self.builder.prepare_markup(
# --> 322                  markup, from_encoding, exclude_encodings=exclude_encodings)):
#     323             self.reset()
#     324             try:
#
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\builder\_htmlparser.py in prepare_markup(self, markup, user_specified_encoding, document_declared_encoding, exclude_encodings)
#     324         try_encodings = [user_specified_encoding, document_declared_encoding]
#     325         dammit = UnicodeDammit(markup, try_encodings, is_html=True,
# --> 326                                exclude_encodings=exclude_encodings)
#     327         yield (dammit.markup, dammit.original_encoding,
#     328                dammit.declared_html_encoding,
#
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\dammit.py in __init__(self, markup, override_encodings, smart_quotes_to, is_html, exclude_encodings)
#     443
#     444         u = None
# --> 445         for encoding in self.detector.encodings:
#     446             markup = self.detector.markup
#     447             u = self._convert_from(encoding)
#
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\dammit.py in encodings(self)
#     307         # encoding.
#     308         if self.chardet_encoding is None:
# --> 309             self.chardet_encoding = chardet_dammit(self.markup)
#     310         if self._usable(self.chardet_encoding, tried):
#     311             yield self.chardet_encoding
#
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\dammit.py in chardet_dammit(s)
#      35             if isinstance(s, str):
#      36                 return None
# ---> 37             return chardet.detect(s)['encoding']
#      38         #import chardet.constants
#      39         #chardet.constants._debug = 1
#
# C:\ProgramData\Anaconda3\lib\site-packages\chardet\__init__.py in detect(byte_str)
#      36             byte_str = bytearray(byte_str)
#      37     detector = UniversalDetector()
# ---> 38     detector.feed(byte_str)
#      39     return detector.close()
#
# C:\ProgramData\Anaconda3\lib\site-packages\chardet\universaldetector.py in feed(self, byte_str)
#     209                 self._charset_probers.append(Latin1Prober())
#     210             for prober in self._charset_probers:
# --> 211                 if prober.feed(byte_str) == ProbingState.FOUND_IT:
#     212                     self.result = {'encoding': prober.charset_name,
#     213                                    'confidence': prober.get_confidence(),
#
# C:\ProgramData\Anaconda3\lib\site-packages\chardet\charsetgroupprober.py in feed(self, byte_str)
#      69             if not prober.active:
#      70                 continue
# ---> 71             state = prober.feed(byte_str)
#      72             if not state:
#      73                 continue
#
# C:\ProgramData\Anaconda3\lib\site-packages\chardet\eucjpprober.py in feed(self, byte_str)
#      76                                                 char_len)
#      77                     self.distribution_analyzer.feed(byte_str[i - 1:i + 1],
# ---> 78                                                      char_len)
#      79
#      80         self._last_char[0] = byte_str[-1]
#
# KeyboardInterrupt:
