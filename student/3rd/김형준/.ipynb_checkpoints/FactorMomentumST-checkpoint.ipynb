# %% [markdown]
# ## 모멘텀 팩터 숏텀: 지난 1주 간의 주가정보 수집 -> positive 종목 중 5개 추천

# %%
import pandas as pd
from datetime import date, datetime, timedelta
import pandas as pd
import time
import numpy as np

import FinanceDataReader as fdr
# from pykrx import stock

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# %matplotlib inline

# %%
mpl.rcParams['axes.unicode_minus'] = False

from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="./malgun.ttf").get_name()
rc('font', family=font_name)

# %%
recommendationCount = 5

# %%
def getMomentum(tickersDF, start, end):
    positiveTickers = []
    for eachTicker in tickersDF.Ticker:
        eachPriceForWeekDF = fdr.DataReader(symbol = eachTicker, start = start, end = end)
        # 부동산 ticker 배제
        if not eachPriceForWeekDF.empty:
            # 시작일 기준 1주일 간의 수익률 계산
            eachYield = (eachPriceForWeekDF.Close[-1] - eachPriceForWeekDF.Close[0]) / eachPriceForWeekDF.Close[0]
            eachStd = np.std(eachPriceForWeekDF.Close)
            eachAdjustedYield = eachYield / eachStd
            if (eachYield > 0):
                eachPositiveTickers = []
                eachPositiveTickers.append(eachTicker)
                eachPositiveTickers.append(eachYield)
                eachPositiveTickers.append(eachStd)
                eachPositiveTickers.append(eachAdjustedYield)
                positiveTickers.append(eachPositiveTickers)
            else:
                pass
        else:
#             print(eachTicker + " is a real estate")
            pass
            
    positiveTickersDF = pd.DataFrame(positiveTickers, columns = ["Ticker", "Yield", "Std", "AdjustedYield"])
    positiveTickersDF = positiveTickersDF[positiveTickersDF.AdjustedYield != float("inf")]
    positiveTickersDF.sort_values("AdjustedYield", ascending=False, ignore_index=True, inplace=True)
    
    return positiveTickersDF

# %%
def getRcmdDFByYield(commonStockTickersDf, positiveTickersDF, targetMarket):
    commonStockTickersDF = pd.merge(commonStockTickersDf, positiveTickersDF, how="inner")
    if (targetMarket == "KRX"):
        rcmdDF = commonStockTickersDF.sort_values("Yield", ascending=False, ignore_index=True)[:recommendationCount]
    else:
        tmpDF = commonStockTickersDf[commonStockTickersDf.Market == targetMarket]
        tmpDF = pd.merge(tmpDF, positiveTickersDF, how="inner")
        rcmdDF = tmpDF.sort_values("Yield", ascending=False, ignore_index=True)[:recommendationCount]
    return rcmdDF

# %%
def getRcmdDFByAdjustedYield(commonStockTickersDf, positiveTickersDF, targetMarket):
    commonStockTickersDF = pd.merge(commonStockTickersDf, positiveTickersDF, how="inner")
    if (targetMarket == "KRX"):
        rcmdDF = commonStockTickersDF.sort_values("AdjustedYield", ascending=False, ignore_index=True)[:recommendationCount]
    else:
        tmpDF = commonStockTickersDf[commonStockTickersDf.Market == targetMarket]
        tmpDF = pd.merge(tmpDF, positiveTickersDF, how="inner")
        rcmdDF = tmpDF.sort_values("AdjustedYield", ascending=False, ignore_index=True)[:recommendationCount]
    return rcmdDF

# %%
def getTickersDF(targetDate):
    tickersDF = pd.read_csv("./tickersDF.csv", encoding="ms949", dtype = {"Ticker":str}, index_col=False)
    tickersDF = tickersDF[tickersDF.Sector.notnull()].reset_index(drop=True)
    dropList = []
    tmpIndex = 0
    for eachListingDate in tickersDF.ListingDate:
        if (datetime.strptime(eachListingDate, "%Y-%m-%d") + timedelta(targetDate) > nowDate):
            dropList.append(tmpIndex)
        else :
            pass
        tmpIndex = tmpIndex + 1
    tickersDF = tickersDF.drop(index = dropList).reset_index(drop=True)
    return tickersDF

# %% [markdown]
# ### 1. 기초정보 수집

# %%
nowDate = datetime.today()

startDate = (nowDate - timedelta(7)).strftime("%Y%m%d")
endDate = (nowDate - timedelta(1)).strftime("%Y%m%d")

testStartDate = (nowDate - timedelta(14)).strftime("%Y%m%d")
testEndDate = (nowDate - timedelta(8)).strftime("%Y%m%d")

today = nowDate.strftime("%Y%m%d")

# %%
tickersDF = getTickersDF(8)
tickersDF.tail(1)
# Out:
#       Ticker  Market Name         Sector                        Industry  \
# 2347  238490  KOSDAQ   힘스  특수 목적용 기계 제조업  OLED Mask 인장기, OLED Mask 검사기 등
#
#      ListingDate SettleMonth Representative               HomePage Region
# 2347  2017-07-20         12월            김주환  http://www.hims.co.kr  인천광역시

# %% [markdown]
# ### 2. 추천종목 5개 선별 (KRX, KOSPI, KOSDAQ, KONEX : 보통주식)

# %%
positiveTickersDF = getMomentum(tickersDF, startDate, endDate)
# Out:
# C:\Users\kkuno\anaconda3\lib\site-packages\ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in double_scalars
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# <!-- ### 추천종목 : 5개(KRX, 모든 주식) -->

# %%
# Yield 기준 추천 5개
krxRcmdDFByYield = getRcmdDFByYield(tickersDF, positiveTickersDF, "KRX")
kospiRcmdDFByYield = getRcmdDFByYield(tickersDF, positiveTickersDF, "KOSPI")
kosdaqRcmdDFByYield = getRcmdDFByYield(tickersDF, positiveTickersDF, "KOSDAQ")
konexRcmdDFByYield = getRcmdDFByYield(tickersDF, positiveTickersDF, "KONEX")

# %%
# AdjustedYield 기준 추천 5개
krxRcmdDFByAdjYield = getRcmdDFByAdjustedYield(tickersDF, positiveTickersDF, "KRX")
kospiRcmdDFByAdjYield = getRcmdDFByAdjustedYield(tickersDF, positiveTickersDF, "KOSPI")
kosdaqRcmdDFByAdjYield = getRcmdDFByAdjustedYield(tickersDF, positiveTickersDF, "KOSDAQ")
konexRcmdDFByAdjYield = getRcmdDFByAdjustedYield(tickersDF, positiveTickersDF, "KONEX")

# %% [markdown]
# ### 3. 추천 종목 가격 추이 시각화 : 1주 전 ~ 현재

# %%
# 시작일 기준 변동 추이 출력
def perfomanceEvaluation(rcmdDF, startDate, endDate, fileName):

    resultList = []
    for i in range(0, len(rcmdDF)):
        tmpDF = fdr.DataReader(symbol = rcmdDF.Ticker[i], start = startDate, end = endDate)
        performance = tmpDF.Close / tmpDF.Close[0]
        performanceDF = performance.to_frame(name = "Performance")
        performanceDF = pd.concat([tmpDF, performanceDF], axis = 1)
        resultList.append(performanceDF)
    
    meanPerformanceList = []
    for i in range(0, len(resultList[0].Performance)):
        sumPerformance = 0
        for j in range(0, len(resultList)):
            sumPerformance = sumPerformance + resultList[j].Performance[i]
        meanPerformance = (sumPerformance / len(resultList))
        meanPerformanceList.append(meanPerformance)
    meanPerformanceDF = pd.DataFrame(meanPerformanceList)
    
    meanPerformanceDF = pd.DataFrame(meanPerformanceList, columns=["MeanPerformance"])
    meanPerformanceDF.index = [resultList[0].index]
    
    x = resultList[0].index.strftime("%Y-%m-%d")
    y = resultList[0].Performance
    y2 = resultList[1].Performance
    y3 = resultList[2].Performance
    y4 = resultList[3].Performance
    y5 = resultList[4].Performance
    y6 = meanPerformanceDF
    
    plt.figure(figsize = (12,7))
    plt.plot(x,y,"b-",label=rcmdDF.Name[0]+rcmdDF.Ticker[0])
    plt.plot(x,y2, "g-",label=rcmdDF.Name[1]+rcmdDF.Ticker[1])
    plt.plot(x,y3, "r-",label=rcmdDF.Name[2]+rcmdDF.Ticker[2])
    plt.plot(x,y4, "y-",label=rcmdDF.Name[3]+rcmdDF.Ticker[3])
    plt.plot(x,y5, "c-",label=rcmdDF.Name[4]+rcmdDF.Ticker[4])
    plt.plot(x,y6, "k-",label="평균", linewidth=4)
    
    for eachX, eachMeanPerformance in zip(x, meanPerformanceDF.MeanPerformance):
#         표에서 잘 보이게 하기 위해 0.01 +
        plt.text(eachX, (eachMeanPerformance + 0.01), str(round(eachMeanPerformance, 2)))
    
    plt.legend(loc="best")
    plt.xlabel("Date")
    plt.ylabel("Performance")
    if not (rcmdDF.Market[0] == rcmdDF.Market[1] == rcmdDF.Market[2] == rcmdDF.Market[3] == rcmdDF.Market[4]):
        plt.title("KRX")
    else:
        plt.title(rcmdDF.Market[0])
    plt.axhline(y=1.0, color='k')
    
    plt.savefig(fileName)

# %%
# Yield 기준 추천 5개
try:
    perfomanceEvaluation(krxRcmdDFByYield, startDate, endDate, (today + "Factor_Momentum_ST_Yield_KRX"))
except:
    pass
try:
    perfomanceEvaluation(kospiRcmdDFByYield, startDate, endDate, (today + "Factor_Momentum_ST_Yield_KOSPI"))
except:
    pass
try:
    perfomanceEvaluation(kosdaqRcmdDFByYield, startDate, endDate, (today + "Factor_Momentum_ST_Yield_KOSDAQ"))
except:
    pass
try:
    perfomanceEvaluation(konexRcmdDFByYield, startDate, endDate, (today + "Factor_Momentum_ST_Yield_KONEX"))
except:
    pass

# %%
krxRcmdDFByYield
# Out:
#    Ticker  Market     Name                            Sector  \
# 0  037270   KOSPI  YG PLUS  자료처리, 호스팅, 포털 및 기타 인터넷 정보매개 서비스업
# 1  270520  KOSDAQ   지엔원에너지          건축기술, 엔지니어링 및 관련 기술 서비스업
# 2  227420   KONEX    도부마스크                         기타 전문 도매업
# 3  297090  KOSDAQ   씨에스베어링                     일반 목적용 기계 제조업
# 4  225850   KONEX      미애부                          생활용품 도매업
#
#                       Industry ListingDate SettleMonth Representative  \
# 0                  광고대행,광고물 제작  2003-08-01         12월            양민석
# 1                            -  2017-08-22         12월            민경천
# 2  1) 마스크 도소매업 2) 모바일 사업 및 R&D  2016-12-28         12월            김충범
# 3         풍력용 선회베어링, 산업용 선회베어링  2019-11-21         12월       조만제, 방성훈
# 4               친환경, 무합성 발효화장품  2015-12-08         12월            강동표
#
#                       HomePage Region     Yield          Std  AdjustedYield
# 0        http://www.ygplus.com  서울특별시  0.734908   547.545432       0.001342
# 1                          NaN    경기도  0.460000   280.132112       0.001642
# 2     http://www.dobumask.asia  서울특별시  0.432787   469.823371       0.000921
# 3  http://www.cs-bearing.co.kr   경상남도  0.415842  1920.781091       0.000216
# 4        http://www.miev.co.kr  서울특별시  0.407143   191.614196       0.002125

# %%
kospiRcmdDFByYield
# Out:
#    Ticker Market     Name                            Sector  \
# 0  037270  KOSPI  YG PLUS  자료처리, 호스팅, 포털 및 기타 인터넷 정보매개 서비스업
# 1  002410  KOSPI     범양건영                            건물 건설업
# 2  024900  KOSPI     덕양산업                     자동차 신품 부품 제조업
# 3  007860  KOSPI       서연                            기타 금융업
# 4  285130  KOSPI    SK케미칼                합성고무 및 플라스틱 물질 제조업
#
#                                Industry ListingDate SettleMonth  \
# 0                           광고대행,광고물 제작  2003-08-01         12월
# 1         토목공사,주택건설,건축공사,난방공사,전기공사,포장공사  1988-05-25         12월
# 2     자동차부품(CRASH PAD,TRIM PANEL) 제조,판매  1997-06-23         12월
# 3  자동차부품(승용차내장품-도어트림,헤드라이닝,승용차시트) 제조,도매  1989-09-09         12월
# 4            PETG 수지, PET 수지, 바이오디젤, 백신  2018-01-05         12월
#
#     Representative                    HomePage Region     Yield           Std  \
# 0              양민석       http://www.ygplus.com  서울특별시  0.734908    547.545432
# 1  강병주, 이동주 (각자대표)        http://www.iby.co.kr  부산광역시  0.370597    484.241675
# 2  윤성희,손동인(각자대표이사)   http://www.duckyang.co.kr  울산광역시  0.301925    134.911230
# 3              유양석      http://www.seo-yon.com    경기도  0.263941    464.912895
# 4          김철, 전광현  http://www.skchemicals.com    경기도  0.253659  11727.744881
#
#    AdjustedYield
# 0       0.001342
# 1       0.000765
# 2       0.002238
# 3       0.000568
# 4       0.000022

# %%
kosdaqRcmdDFByYield
# Out:
#    Ticker  Market    Name                    Sector              Industry  \
# 0  270520  KOSDAQ  지엔원에너지  건축기술, 엔지니어링 및 관련 기술 서비스업                     -
# 1  297090  KOSDAQ  씨에스베어링             일반 목적용 기계 제조업  풍력용 선회베어링, 산업용 선회베어링
# 2  222420  KOSDAQ     쎄노텍           기타 비금속 광물제품 제조업                세라믹 비드
# 3  081150  KOSDAQ    티플랙스            기타 금속 가공제품 제조업   스텐레스봉,판(열간제품) 제조,도매
# 4  088800  KOSDAQ   에이스테크            통신 및 방송 장비 제조업       단말기용안테나,기지국용안테나
#
#   ListingDate SettleMonth Representative                          HomePage  \
# 0  2017-08-22         12월            민경천                               NaN
# 1  2019-11-21         12월       조만제, 방성훈       http://www.cs-bearing.co.kr
# 2  2015-08-06         12월  이승호, 허명구 (각자)            http://www.cenotec.com
# 3  2009-04-23         12월            김영국            http://www.tplex.co.kr
# 4  2006-03-27         12월  구관영,홍익표(각자대표)  http://www.aceantenna.co.kr/kor/
#
#   Region     Yield          Std  AdjustedYield
# 0    경기도  0.460000   280.132112       0.001642
# 1   경상남도  0.415842  1920.781091       0.000216
# 2   경상남도  0.406250   347.110933       0.001170
# 3    경기도  0.388430   452.411317       0.000859
# 4  인천광역시  0.336449  1591.100248       0.000211

# %%
konexRcmdDFByYield
# Out:
#    Ticker Market   Name                                 Sector  \
# 0  227420  KONEX  도부마스크                              기타 전문 도매업
# 1  225850  KONEX    미애부                               생활용품 도매업
# 2  183410  KONEX  골프존데카  측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외
# 3  278990  KONEX  파인이엠텍      전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업
# 4  267060  KONEX  명진홀딩스                        수산물 가공 및 저장 처리업
#
#                       Industry ListingDate SettleMonth Representative  \
# 0  1) 마스크 도소매업 2) 모바일 사업 및 R&D  2016-12-28         12월            김충범
# 1               친환경, 무합성 발효화장품  2015-12-08         12월            강동표
# 2                      골프거리측정기  2013-11-12         12월            정주명
# 3              태양광ESS,휴대폰 액세서리  2017-10-31         12월            홍지태
# 4            연어 가공 식품(필렛, HMR)  2017-08-24         12월            정상익
#
#                       HomePage Region     Yield         Std  AdjustedYield
# 0     http://www.dobumask.asia  서울특별시  0.432787  469.823371       0.000921
# 1        http://www.miev.co.kr  서울특별시  0.407143  191.614196       0.002125
# 2      http://www.golfbuddy.kr    경기도  0.397059  189.145447       0.002099
# 3  http://www.fineemtech.co.kr    경기도  0.312036  939.361485       0.000332
# 4   http://www.salmonkorea.com  서울특별시  0.297619  133.529023       0.002229

# %%
# AdjustedYield 기준 추천 5개
try:
    perfomanceEvaluation(krxRcmdDFByAdjYield, startDate, endDate, (today + "Factor_Momentum_ST_AdjYield_KRX"))
except:
    pass
try:
    perfomanceEvaluation(kospiRcmdDFByAdjYield, startDate, endDate, (today + "Factor_Momentum_ST_AdjYield_KOSPI"))
except:
    pass
try:    
    perfomanceEvaluation(kosdaqRcmdDFByAdjYield, startDate, endDate, (today + "Factor_Momentum_ST_AdjYield_KOSDAQ"))
except:
    pass
try:    
    perfomanceEvaluation(konexRcmdDFByAdjYield, startDate, endDate, (today + "Factor_Momentum_ST_AdjYield_KONEX"))
except:
    pass

# %%
krxRcmdDFByAdjYield
# Out:
#    Ticker  Market     Name           Sector       Industry ListingDate  \
# 0  032860  KOSDAQ   글로스퍼랩스  해체, 선별 및 원료 재생업           철스크랩  1997-07-04
# 1  179720   KONEX     옐로페이   소프트웨어 개발 및 공급업     전자지급결제 서비스  2013-07-01
# 2  900120  KOSDAQ   씨케이에이치           기타 금융업         건강보조식품  2010-03-31
# 3  011080  KOSDAQ    형지I&C         봉제의복 제조업           남성셔츠  2004-07-02
# 4  064090  KOSDAQ  에프앤리퍼블릭        상품 종합 도매업  CCTV CAMERA 등  2002-12-17
#
#   SettleMonth Representative                    HomePage  Region     Yield  \
# 0         12월            이대식  http://www.glosferlabs.com     경기도  0.126437
# 1         12월            이상규      http://www.yelopay.com   서울특별시  0.223176
# 2         06월            린진성                         NaN  케이맨 제도  0.078704
# 3         12월            최혜원   http://www.woosunginc.com   서울특별시  0.039216
# 4         12월            오창근   http://www.fnrepublic.com   서울특별시  0.161088
#
#          Std  AdjustedYield
# 0   9.282241       0.013621
# 1  16.644519       0.013408
# 2   6.046487       0.013016
# 3   7.002857       0.005600
# 4  31.587339       0.005100

# %%
kospiRcmdDFByAdjYield
# Out:
#    Ticker Market     Name              Sector  \
# 0  018470  KOSPI    조일알미늄         1차 비철금속 제조업
# 1  012800  KOSPI       대창         1차 비철금속 제조업
# 2  011420  KOSPI  갤럭시아에스엠            스포츠 서비스업
# 3  024900  KOSPI     덕양산업       자동차 신품 부품 제조업
# 4  027740  KOSPI      마니커  도축, 육류 가공 및 저장 처리업
#
#                                             Industry ListingDate SettleMonth  \
# 0                                        알루미늄판 제조,도매  1988-11-22         12월
# 1                                     황동봉,동합금괴 제조,판매  1989-12-05         12월
# 2                                   스포츠중계권,스포츠마케팅,광고  1989-11-14         12월
# 3                  자동차부품(CRASH PAD,TRIM PANEL) 제조,판매  1997-06-23         12월
# 4  닭고기,햄,계육가공제품,계육,육가공제품 제조,판매,유통/양계관련사업/부동산임대/수출입대행  2002-10-29         12월
#
#     Representative                   HomePage Region     Yield         Std  \
# 0          이영호,박동수   http://www.choilal.co.kr   경상북도  0.011236    2.925748
# 1         조시영, 김옥렬    http://www.brassone.com    경기도  0.066964   25.806976
# 2              이반석      http://galaxiasme.com  서울특별시  0.059289   25.179357
# 3  윤성희,손동인(각자대표이사)  http://www.duckyang.co.kr  울산광역시  0.301925  134.911230
# 4              최상웅   http://www.maniker.co.kr    경기도  0.031146   13.948477
#
#    AdjustedYield
# 0       0.003840
# 1       0.002595
# 2       0.002355
# 3       0.002238
# 4       0.002233

# %%
kosdaqRcmdDFByAdjYield
# Out:
#    Ticker  Market     Name           Sector         Industry ListingDate  \
# 0  032860  KOSDAQ   글로스퍼랩스  해체, 선별 및 원료 재생업             철스크랩  1997-07-04
# 1  900120  KOSDAQ   씨케이에이치           기타 금융업           건강보조식품  2010-03-31
# 2  011080  KOSDAQ    형지I&C         봉제의복 제조업             남성셔츠  2004-07-02
# 3  064090  KOSDAQ  에프앤리퍼블릭        상품 종합 도매업    CCTV CAMERA 등  2002-12-17
# 4  106520  KOSDAQ    디지탈옵틱  사진장비 및 광학기기 제조업  휴대폰 및 차량용 카메라렌즈  2012-07-13
#
#   SettleMonth Representative                        HomePage  Region  \
# 0         12월            이대식      http://www.glosferlabs.com     경기도
# 1         06월            린진성                             NaN  케이맨 제도
# 2         12월            최혜원       http://www.woosunginc.com   서울특별시
# 3         12월            오창근       http://www.fnrepublic.com   서울특별시
# 4         12월            곽윤식  http://www.digitaloptics.co.kr     경기도
#
#       Yield        Std  AdjustedYield
# 0  0.126437   9.282241       0.013621
# 1  0.078704   6.046487       0.013016
# 2  0.039216   7.002857       0.005600
# 3  0.161088  31.587339       0.005100
# 4  0.080997  20.109699       0.004028

# %%
konexRcmdDFByAdjYield
# Out:
#    Ticker Market   Name                                 Sector  \
# 0  179720  KONEX   옐로페이                         소프트웨어 개발 및 공급업
# 1  208890  KONEX  에듀파트너                              교육지원 서비스업
# 2  149300  KONEX   아퓨어스                  기초 의약물질 및 생물학적 제제 제조업
# 3  222160  KONEX  바이옵트로  측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외
# 4  267810  KONEX     앙츠                         컴퓨터 및 통신장비 수리업
#
#                     Industry ListingDate SettleMonth Representative  \
# 0                 전자지급결제 서비스  2013-07-01         12월            이상규
# 1                     방과후 교육  2014-12-18         12월       최용섭, 김현균
# 2  실험동물, 연구용피부 및 연구용세포, 연구용역  2019-09-03         12월            최선덕
# 3   PCB 전기 검사기, Screw 자동 체결기  2016-03-10         03월            김완수
# 4                      기술서비스  2017-04-28         12월            박창진
#
#                       HomePage Region     Yield         Std  AdjustedYield
# 0       http://www.yelopay.com  서울특별시  0.223176   16.644519       0.013408
# 1  http://www.edupartner.co.kr  서울특별시  0.219376   84.444064       0.002598
# 2        http://www.apures.com    경기도  0.272727  106.131993       0.002570
# 3     http://www.bioptro.co.kr    경기도  0.245833  104.852277       0.002345
# 4       http://www.iantz.co.kr  서울특별시  0.196172   88.000000       0.002229

# %% [markdown]
# ### 4. 테스트용 추천종목 5개 선별 (KRX, KOSPI, KOSDAQ, KONEX, 보통주식) : 2주 전 ~ 1주 전 기준

# %%
testTickersDF = getTickersDF(15)
testTickersDF.tail(1)
# Out:
#       Ticker  Market Name         Sector                        Industry  \
# 2343  238490  KOSDAQ   힘스  특수 목적용 기계 제조업  OLED Mask 인장기, OLED Mask 검사기 등
#
#      ListingDate SettleMonth Representative               HomePage Region
# 2343  2017-07-20         12월            김주환  http://www.hims.co.kr  인천광역시

# %%
testPositiveTickersDF = getMomentum(testTickersDF, testStartDate, testEndDate)
# Out:
# C:\Users\kkuno\anaconda3\lib\site-packages\ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in double_scalars
#   # Remove the CWD from sys.path while we load stuff.

# %%
testKrxRcmdDFByYield = getRcmdDFByYield(testTickersDF, testPositiveTickersDF, "KRX")
testKospiRcmdDFByYield = getRcmdDFByYield(testTickersDF, testPositiveTickersDF, "KOSPI")
testKosdaqRcmdDFByYield = getRcmdDFByYield(testTickersDF, testPositiveTickersDF, "KOSDAQ")
testKonexRcmdDFByYield = getRcmdDFByYield(testTickersDF, testPositiveTickersDF, "KONEX")

# %%
testKrxRcmdDFByAdjYield = getRcmdDFByAdjustedYield(testTickersDF, testPositiveTickersDF, "KRX")
testKospiRcmdDFByAdjYield = getRcmdDFByAdjustedYield(testTickersDF, testPositiveTickersDF, "KOSPI")
testKosdaqRcmdDFByAdjYield = getRcmdDFByAdjustedYield(testTickersDF, testPositiveTickersDF, "KOSDAQ")
testKonexRcmdDFByAdjYield = getRcmdDFByAdjustedYield(testTickersDF, testPositiveTickersDF, "KONEX")

# %% [markdown]
# ### 5. 테스트용 종목의 성과 평가(전략의 유효성 검증) : 1주 전 ~ 현재

# %%
# Yield 기준 성과 테스트
try:
    perfomanceEvaluation(testKrxRcmdDFByYield, startDate, endDate, (today + "Factor_Momentum_ST_Yield_KRX_Test"))
except:
    pass
try:
    perfomanceEvaluation(testKospiRcmdDFByYield, startDate, endDate, (today + "Factor_Momentum_ST_Yield_KOSPI_Test"))
except:
    pass
try:
    perfomanceEvaluation(testKosdaqRcmdDFByYield, startDate, endDate, (today + "Factor_Momentum_ST_Yield_KOSDAQ_Test"))
except:
    pass
try:
    perfomanceEvaluation(testKonexRcmdDFByYield, startDate, endDate, (today + "Factor_Momentum_ST_Yield_KONEX_Test"))
except:
    pass

# %%
# AdjustedYield 기준 성과 테스트
try:
    perfomanceEvaluation(testKrxRcmdDFByAdjYield, startDate, endDate, (today + "Factor_Momentum_ST_AdjYield_KRX_Test"))
except:
    pass
try:
    perfomanceEvaluation(testKospiRcmdDFByAdjYield, startDate, endDate, (today + "Factor_Momentum_ST_AdjYield_KOSPI_Test"))
except:
    pass
try:
    perfomanceEvaluation(testKosdaqRcmdDFByAdjYield, startDate, endDate, (today + "Factor_Momentum_ST_AdjYield_KOSDAQ_Test"))
except:
    pass
try:
    perfomanceEvaluation(testKonexRcmdDFByAdjYield, startDate, endDate, (today + "Factor_Momentum_ST_AdjYield_KONEX_Test"))
except:
    pass
