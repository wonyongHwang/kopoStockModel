# %%
import pandas as pd
df = pd.read_html('https://kind.krx.co.kr/corpgeneral/corpList.do?method=download&marketType=stockMkt')
df[0]
# Out:
#             회사명    종목코드               업종
# 0        AJ네트웍스   95570  산업용 기계 및 장비 임대업  \
# 1       BNK금융지주  138930           기타 금융업
# 2           DSR  155660      1차 비철금속 제조업
# 3            GS   78930           기타 금융업
# 4     HDC현대산업개발  294870           건물 건설업
# ..          ...     ...              ...
# 824     현대코퍼레이션   11760        상품 종합 도매업
# 825  현대코퍼레이션홀딩스  227840   음·식료품 및 담배 도매업
# 826          화신   10690    자동차 신품 부품 제조업
# 827      효성첨단소재  298050         화학섬유 제조업
# 828        흥아해운    3280           해상 운송업
#
#                                                 주요제품         상장일  결산월
# 0                                렌탈(파렛트, OA장비, 건설장비)  2015-08-21  12월  \
# 1                                             금융지주회사  2011-03-30  12월
# 2                                             합섬섬유로프  2013-05-15  12월
# 3                                        지주회사/부동산 임대  2004-08-05  12월
# 4                             외주주택, 자체공사, 일반건축, 토목 등  2018-06-12  12월
# ..                                               ...         ...  ...
# 824  자동차,철강,기계,선박,플랜트,컴퓨터,전자제품 수출,수출입대행/자원(탄광,유전) 개발  1977-12-01  12월
# 825                                      브랜드사업, 육류유통  2015-10-23  12월
# 826                    자동차엔진부품(ARM류,C/MBR류),자동차부품 제조  1994-01-14  12월
# 827                                         PET타이어코드  2018-07-13  12월
# 828                                   외항화물운송업(케미컬탱커)  1976-06-29  12월
#
#                         대표자명                                     홈페이지     지역
# 0                        손삼달                   http://www.ajnet.co.kr  서울특별시
# 1                        빈대인                     http://www.bnkfg.com  부산광역시
# 2                        홍석빈                       http://www.dsr.com  부산광역시
# 3         허태수, 홍순기 (각자 대표이사)                                      NaN  서울특별시
# 4    최익훈, 정익희, 김회언 (각자 대표이사)                   http://www.hdc-dvp.com  서울특별시
# ..                       ...                                      ...    ...
# 824    정몽혁, 김원갑, 장안석(각자대표이사)             http://www.hyundaicorp.co.kr  서울특별시
# 825         정몽혁, 김원갑(각자대표이사)       http://www.hyundaicorpholdings.com  서울특별시
# 826                 정서진, 장의호                 http://www.hwashin.co.kr   경상북도
# 827                      조용수  http://www.hyosungadvancedmaterials.com  서울특별시
# 828                      이환구                   http://www.heung-a.com  서울특별시
#
# [829 rows x 9 columns]

# %%
from bs4 import BeautifulSoup 

url = 'https://finance.naver.com/item/main.nhn?code=035720'
table_df_list = pd.read_html(url, encoding='euc-kr')

# %%
table_df_list[0]
# Out:
#                     0                                        1
# 0  전일  57,200  57,200  고가  58,20058,200  (상한가  74,30074,300  )  \
# 1    시가  57,40057,400        저가  57,20057,200  (하한가  40,100  )
#
#                            2
# 0  거래량  1,367,946  1,367,946
# 1   거래대금  79,000  79,000  백만

# %%
table_df_list[1]
# Out:
#      매도상위       거래량    매수상위       거개량
# 0     NaN       NaN     NaN       NaN
# 1    키움증권  246362.0  신한투자증권  261377.0
# 2      삼성  158166.0    키움증권  187045.0
# 3  미래에셋증권  149663.0    한국증권  138560.0
# 4  신한투자증권  133225.0  미래에셋증권  115996.0
# 5  NH투자증권  117375.0  NH투자증권  112886.0
# 6  외국계추정합   30180.0  -28747    1433.0

# %%
table_df_list[2]
# Out:
#       날짜       종가        전일비       외국인        기관
# 0    NaN      NaN        NaN       NaN       NaN
# 1  05/19  57900.0    상향  700  132387.0  236997.0
# 2  05/18  57200.0    하향  500 -270049.0  -94270.0
# 3  05/17  57700.0  상향  1,600  113823.0  676450.0
# 4  05/16  56100.0    하향  700 -126423.0  -86655.0
# 5  05/15  56800.0    상향  200   64629.0  -22052.0
# 6  05/12  56600.0    상향  600  211421.0   23578.0
# 7    NaN      NaN        NaN       NaN       NaN

# %%
table_df_list[3]
# Out:
#        주요재무정보  최근 연간 실적                                 최근 분기 실적
#        주요재무정보   2020.12   2021.12   2022.12 2023.12(E)   2021.12   2022.03
#        주요재무정보    IFRS연결    IFRS연결    IFRS연결     IFRS연결    IFRS연결    IFRS연결
# 0         매출액  41568.00  61367.00  71068.00   82816.00  17857.00  16517.00  \
# 1        영업이익   4559.00   5949.00   5803.00    5941.00   1066.00   1587.00
# 2       당기순이익   1734.00  16462.00  10626.00    5269.00   2241.00  13221.00
# 3       영업이익률     10.97      9.69      8.17       7.17      5.97      9.61
# 4        순이익률      4.17     26.82     14.95       6.36     12.55     80.05
# 5   ROE(지배주주)      2.70     17.10     13.54       4.51     17.10     27.55
# 6        부채비율     60.94     67.62     69.70        NaN     67.62     64.10
# 7        당좌비율    162.77    146.88    149.38        NaN    146.88    138.52
# 8         유보율  13881.01  21260.57  25032.00        NaN  21260.57  24271.32
# 9      EPS(원)    355.00   3132.00   3037.00    1053.00    172.00   2922.00
# 10     PER(배)    219.25     35.92     17.48      54.97     35.92     19.19
# 11     BPS(원)  14647.00  23018.00  22893.00   24594.00  23018.00  25977.00
# 12     PBR(배)      5.32      4.89      2.32       2.35      4.89      4.10
# 13   주당배당금(원)     30.00     53.00     60.00      60.00       NaN       NaN
# 14   시가배당률(%)      0.04      0.05      0.11        NaN       NaN       NaN
# 15    배당성향(%)      8.29      1.65      1.94        NaN       NaN       NaN
#
#
#      2022.06   2022.09   2022.12 2023.03(E)
#       IFRS연결    IFRS연결    IFRS연결     IFRS연결
# 0   18223.00  18587.00  17741.00   18259.00
# 1    1710.00   1503.00   1003.00    1227.00
# 2    1012.00   1372.00  -4979.00    1262.00
# 3       9.38      8.09      5.65       6.72
# 4       5.55      7.38    -28.07       6.91
# 5      23.47     15.35     13.54        NaN
# 6      67.17     66.56     69.70        NaN
# 7     144.62    139.95    149.38        NaN
# 8   24578.67  24863.04  25032.00        NaN
# 9     152.00    239.00   -279.00     244.00
# 10     13.98     16.37     17.48     238.28
# 11  25729.00  26253.00  22893.00        NaN
# 12      2.72      2.18      2.32        NaN
# 13       NaN       NaN       NaN        NaN
# 14       NaN       NaN       NaN        NaN
# 15       NaN       NaN       NaN        NaN

# %%
table_df_list[4]
# Out:
#            종목명  카카오*035720 NAVER*035420 아프리카TV*067160 자이언트스텝*289220
# 0          현재가       57900       216500         79400         17710  \
# 1         전일대비     상향  700    상향  4,000     상향  1,800       상향  300
# 2          등락률  상향  +1.22%   상향  +1.88%    상향  +2.32%    상향  +1.72%
# 3      시가총액(억)      257043       355166          9126          3917
# 4     외국인비율(%)       26.16        48.21         21.53          1.94
# 5       매출액(억)       17741        22717           799           119
# 6      영업이익(억)        1003         3365           155           -61
# 7    조정영업이익(억)        1003         3365           155           -61
# 8   영업이익증가율(%)      -33.28         1.89        -25.18        -11.77
# 9     당기순이익(억)       -4979         1318            31           -40
# 10    주당순이익(원)     -278.76       907.03        278.33       -178.78
# 11      ROE(%)       13.54         3.29         26.52         -9.98
# 12      PER(%)       19.06        55.15         15.28        -31.62
# 13      PBR(배)        2.53         1.39          3.59          3.29
#
#    키다리스튜디오*020120
# 0            6910
# 1          상향  40
# 2      상향  +0.58%
# 3            2554
# 4            0.48
# 5             383
# 6             -43
# 7             -43
# 8         -387.20
# 9             -73
# 10        -198.18
# 11          -1.14
# 12         -88.59
# 13           0.94

# %%
table_df_list[5]
# Out:
#           0               1
# 0      시가총액  25조  7,043  억원
# 1    시가총액순위         코스피 12위
# 2     상장주식수       443943687
# 3  액면가l매매단위     100원  l  1주

# %%
table_df_list[6]
# Out:
#              0          1
# 0  외국인한도주식수(A)  443943687
# 1  외국인보유주식수(B)  116150577
# 2  외국인소진율(B/A)     26.16%

# %%
table_df_list[7]
# Out:
#            0                  1
# 0  투자의견l목표주가  4.00매수  l  77,842
# 1   52주최고l최저  87,400  l  46,500

# %%
table_df_list[8]
# Out:
#                    0                  1
# 0   PERlEPS(2022.12)  19.06배  l  3,037원
# 1          추정PERlEPS  55.00배  l  1,053원
# 2  PBRlBPS (2022.12)  2.53배  l  22,893원
# 3      배당수익률l2022.12              0.10%

# %%
table_df_list[9]
# Out:
#           0       1
# 0  동일업종 PER  29.76배
# 1  동일업종 등락률  +1.61%

# %%
table_df_list[10]
# Out:
#         매도잔량 호가(20분지연)      매수잔량
# 0        NaN       NaN       NaN
# 1    16850.0     58900       NaN
# 2    28822.0     58800       NaN
# 3    13625.0     58700       NaN
# 4    29237.0     58600       NaN
# 5    45857.0     58500       NaN
# 6    26396.0     58400       NaN
# 7    21370.0     58300       NaN
# 8    46148.0     58200       NaN
# 9    33303.0     58100       NaN
# 10   74678.0     58000       NaN
# 11       NaN       NaN       NaN
# 12       NaN     57900     337.0
# 13       NaN     57800    9496.0
# 14       NaN     57700   12445.0
# 15       NaN     57600   18230.0
# 16       NaN     57500   24890.0
# 17       NaN     57400   25506.0
# 18       NaN     57300   17467.0
# 19       NaN     57200   15605.0
# 20       NaN     57100    5977.0
# 21       NaN     57000   14637.0
# 22       NaN       NaN       NaN
# 23  336286.0      잔량합계  144590.0

# %%
table_df_list[11]
# Out:
#           업체명       거래량         전일비
# 0        삼성전자   68400.0   상향  2,200
# 1         현대차  205500.0   하향  1,000
# 2    POSCO홀딩스  364500.0   하향  8,500
# 3   LG에너지솔루..  552000.0  하향  10,000
# 4       NAVER  216500.0   상향  4,000
# 5         NaN       NaN         NaN
# 6         HMM   18360.0      상향  80
# 7          금양   54700.0     상향  700
# 8       DB하이텍   62500.0   상향  2,800
# 9       이엔플러스   10640.0   상향  1,060
# 10      한미반도체   25950.0   상향  4,600

# %%
table_df_list[12]
# Out:
#          업체명       거래량         전일비
# 0       에코프로  532000.0  하향  33,000
# 1      바이오니아   51600.0     상향  800
# 2        소룩스   21300.0  상한가  4,900
# 3      나노신소재  128500.0   하향  2,300
# 4       뉴로메카   37900.0     상향  200
# 5        NaN       NaN         NaN
# 6      미래반도체   27600.0  상한가  6,350
# 7     에코프로비엠  226500.0   하향  5,000
# 8       엘앤에프  237000.0  하향  15,500
# 9      동진쎄미켐   35200.0   상향  4,400
# 10  오픈엣지테크..   19950.0     상향  800
